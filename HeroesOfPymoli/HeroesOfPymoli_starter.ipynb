# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
file= "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
gamer_df= pd.read_csv(file)

# %%
gamer_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
Players=gamer_df[["SN"]].value_counts()
Players
# Out:
# SN
# Lisosia93       5
# Iral74          4
# Idastidru52     4
# Aina42          3
# Iri67           3
#                ..
# Lisossala30     1
# Lisossanya98    1
# Lisotesta51     1
# Lisovynya38     1
# Adairialis76    1
# Length: 576, dtype: int64

# %%
Total_Players = pd.DataFrame({"Total Players":[576]})
Total_Players
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
number_purchases =gamer_df["Purchase ID"].value_counts()
number_purchases
# Out:
# 779    1
# 243    1
# 265    1
# 264    1
# 263    1
#       ..
# 517    1
# 516    1
# 515    1
# 514    1
# 0      1
# Name: Purchase ID, Length: 780, dtype: int64

# %%
average_price= round(gamer_df["Price"].mean(),2)
average_price
# Out:
# 3.05

# %%
total_revenue= gamer_df["Price"].sum()
total_revenue
# Out:
# 2379.77

# %%
unique_items= gamer_df["Item Name"].value_counts()
unique_items
# Out:
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Fiery Glass Crusader                             9
# Nirvana                                          9
# Persuasion                                       9
#                                                 ..
# Exiled Mithril Longsword                         1
# Endbringer                                       1
# Celeste                                          1
# The Decapitator                                  1
# Alpha, Reach of Ending Hope                      1
# Name: Item Name, Length: 179, dtype: int64

# %%
Purchasing_Analysis = pd.DataFrame({"Number of Unique Items":[179], "Average Price": ["$3.05"], "Number of Purchases":[780], "Total Revenue": ["$2,379.77"]})
Purchasing_Analysis
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     179         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#count of Genders
gender= gamer_df["Gender"].value_counts()
gender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
#Total count of All genders
total = gender.sum()
total
# Out:
# 780

# %%
#Summary of Gender Count and Percentage of players
gender_count_df =round(pd.DataFrame({"Total Count": gender,"Percentage of Players":[(652/780)*100,(113/780)*100,(15/780)*100]}),2)
gender_count_df
# Out:
#                        Total Count  Percentage of Players
# Male                           652                  83.59
# Female                         113                  14.49
# Other / Non-Disclosed           15                   1.92

# %%
#Alternative way of showing the same data

Gender_Demo= round(pd.DataFrame({"":["Male","Female","Other/Non Disclosed"], 
                           "Total Count":[652, 113, 15],
                           "Percentage of Players":[(652/780)*100,(113/780)*100,(15/780)*100]
                          }),2)
Gender_Demo
# Out:
#                         Total Count  Percentage of Players
# 0                 Male          652                  83.59
# 1               Female          113                  14.49
# 2  Other/Non Disclosed           15                   1.92

# %%
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchasing_df= gamer_df[["Gender","Price"]]
purchasing_df.head()
# Out:
#   Gender  Price
# 0   Male   3.53
# 1   Male   1.56
# 2   Male   4.88
# 3   Male   3.27
# 4   Male   1.44

# %%
purchase_group= purchasing_df.groupby(["Gender"])
average_price_df= round(purchase_group.mean(),2)
average_price_df
# Out:
#                        Price
# Gender
# Female                  3.20
# Male                    3.02
# Other / Non-Disclosed   3.35

# %%
total_price_df= purchase_group.sum()
total_price_df
# Out:
#                          Price
# Gender
# Female                  361.94
# Male                   1967.64
# Other / Non-Disclosed    50.19

# %%
Purchasing_Analysis_df=pd.DataFrame({"Gender":["Male","Female","Other/Non Disclosed"], 
                           "Purchase Count":[652, 113, 15],
                           "Average Purchase Price":[3.02,3.20,3.35],
                            "Total Purchase Value":["$1967.64","$361.94","$50.19"]
                          })
Purchasing_Analysis_df
# Out:
#                 Gender  Purchase Count  Average Purchase Price  \
# 0                 Male             652                    3.02
# 1               Female             113                    3.20
# 2  Other/Non Disclosed              15                    3.35
#
#   Total Purchase Value
# 0             $1967.64
# 1              $361.94
# 2               $50.19

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
gamer_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#created Bins in which data will be held
bins =[0,9,14,19,24,29,34,39,50]

#names for bins

age_groups = ["<10", "10-14","15-19","20-24","25-29","30-34","35-39","40+"]

# %%
gamer_df["Age Ranges"]=pd.cut(gamer_df["Age"],bins,labels=age_groups, include_lowest= True)
gamer_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Ranges
# 0  Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                          Frenzied Scimitar   1.56        40+
# 2                               Final Critic   4.88      20-24
# 3                                Blindscythe   3.27      20-24
# 4                                       Fury   1.44      20-24

# %%
gamer_df[["Age Ranges","Age"]].head()
# Out:
#   Age Ranges  Age
# 0      20-24   20
# 1        40+   40
# 2      20-24   24
# 3      20-24   24
# 4      20-24   23

# %%
#Group by age ranges
age_ranges_df=gamer_df.groupby("Age Ranges")
age_ranges_df["Age"].count()
# Out:
# Age Ranges
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: Age, dtype: int64

# %%
#Data Frame
Demographic_Summary_df=round(pd.DataFrame({"":["<10", "10-14","15-19","20-24","25-29","30-34","35-39","40+"], 
                                     "Total Count":[23,28,136,365,101,73,41,13],
                                    "Percentage of Players":[(23/780)*100,(28/780)*100,(136/780)*100,(365/780)*100,(101/780)*100,(73/780)*100,(41/780)*100,(13/780)*100],
                                   }),2)
                        
Demographic_Summary_df
# Out:
#           Total Count  Percentage of Players
# 0    <10           23                   2.95
# 1  10-14           28                   3.59
# 2  15-19          136                  17.44
# 3  20-24          365                  46.79
# 4  25-29          101                  12.95
# 5  30-34           73                   9.36
# 6  35-39           41                   5.26
# 7    40+           13                   1.67

# %%
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#created Bins in which data will be held
bins =[0,9,14,19,24,29,34,39,50]

#names for bins

ages_df = ["<10", "10-14","15-19","20-24","25-29","30-34","35-39","40+"]

# %%
gamer_df["Age Ranges"]=pd.cut(gamer_df["Age"],bins,labels=age_groups, include_lowest= True)
gamer_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Ranges
# 0  Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                          Frenzied Scimitar   1.56        40+
# 2                               Final Critic   4.88      20-24
# 3                                Blindscythe   3.27      20-24
# 4                                       Fury   1.44      20-24

# %%
money_df=gamer_df[["Age Ranges","Price"]]
money_df.head()
# Out:
#   Age Ranges  Price
# 0      20-24   3.53
# 1        40+   1.56
# 2      20-24   4.88
# 3      20-24   3.27
# 4      20-24   1.44

# %%
Follow_the_money_df= money_df.groupby(["Age Ranges"])
Follow_the_money_df.sum()
# Out:
#               Price
# Age Ranges
# <10           77.13
# 10-14         82.78
# 15-19        412.89
# 20-24       1114.06
# 25-29        293.00
# 30-34        214.00
# 35-39        147.67
# 40+           38.24

# %%
round(Follow_the_money_df.mean(),2)
# Out:
#             Price
# Age Ranges
# <10          3.35
# 10-14        2.96
# 15-19        3.04
# 20-24        3.05
# 25-29        2.90
# 30-34        2.93
# 35-39        3.60
# 40+          2.94

# %%
Money_Talks_df=pd.DataFrame({"Age Ranges":["<10", "10-14","15-19","20-24","25-29","30-34","35-39","40+"], 
                           "Purchase Count":[23,28,136,365,101,73,41,13],
                           "Average Purchase Price":["$3.35","2.96","$3.04","$3.05","$2.90","$2.93","$3.60","$2.94"],
                            "Total Purchase Value":["$77.13","$82.78","$412.89","$1,114.06","$293.00","$214.00","$147.67", "$38.24"]
                          })
Money_Talks_df
# Out:
#   Age Ranges  Purchase Count Average Purchase Price Total Purchase Value
# 0        <10              23                  $3.35               $77.13
# 1      10-14              28                   2.96               $82.78
# 2      15-19             136                  $3.04              $412.89
# 3      20-24             365                  $3.05            $1,114.06
# 4      25-29             101                  $2.90              $293.00
# 5      30-34              73                  $2.93              $214.00
# 6      35-39              41                  $3.60              $147.67
# 7        40+              13                  $2.94               $38.24

# %%
#Turns on custome formatting 
#pd.options.display.float_format = '${:,.2f}'.format

# %%
#This will turn off all float formatting
#pd.options.display.float_format= None
# Out:
# NoneType

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Uniqe SN name
name_df= gamer_df[["SN","Price","Item Name"]]
name_df.value_counts()
# Out:
# SN            Price  Item Name
# Zontibe81     3.79   Arcane Gem                                   1
# Frichjask31   4.43   Deluge, Edge of the West                     1
# Haisrisuir60  4.19   Final Critic                                 1
#               2.67   Abyssal Shard                                1
# Haillyrgue51  4.60   Dawn                                         1
#                                                                  ..
# Marokian45    3.53   Extraction, Quickblade Of Trembling Hands    1
# Marjask87     1.44   Suspension                                   1
# Marirrasta50  4.66   Endbringer                                   1
# Marim28       3.33   Lifebender                                   1
# Adairialis76  2.28   Twilight's Carver                            1
# Length: 780, dtype: int64

# %%
#creat dataframe of the average for each screen name
sn_group =name_df.groupby(["SN"])

cost_average= round(sn_group.mean(),2)
cost_average.head()

sort2_df = cost_average.sort_values("Price",ascending=False )
sort2_df.head(10)
# Out:
#                 Price
# SN
# Dyally87         4.99
# Yarithsurgue62   4.94
# Chanirrasta87    4.94
# Lirtilsa71       4.94
# Ririp86          4.94
# Mindossa76       4.93
# Chadjask77       4.93
# Aeda94           4.91
# Filurarn35       4.91
# Aerithnuphos61   4.91

# %%
#creat dataframe of the total price for each screen name
cost_sum=sn_group.sum()
cost_sum.head()

sort3_df = cost_sum.sort_values("Price",ascending=False )
sort3_df.head()
# Out:
#              Price
# SN
# Lisosia93    18.96
# Idastidru52  15.45
# Chamjask73   13.83
# Iral74       13.62
# Iskadarya95  13.10

# %%
#creat dataframe of the count for each screen name
cost_count=sn_group.count()
cost_count.head()

sort4_df = cost_count.sort_values("Price",ascending=False )
sort4_df.head()
# Out:
#              Price  Item Name
# SN
# Lisosia93        5          5
# Iral74           4          4
# Idastidru52      4          4
# Asur53           3          3
# Inguron55        3          3

# %%
#Indexed Sn to isolate SN
df = name_df.set_index("SN")
df.head()
# Out:
#                Price                                  Item Name
# SN
# Lisim78         3.53  Extraction, Quickblade Of Trembling Hands
# Lisovynya38     1.56                          Frenzied Scimitar
# Ithergue48      4.88                               Final Critic
# Chamassasya86   3.27                                Blindscythe
# Iskosia90       1.44                                       Fury

# %%
#Locked Sn based off of the total purchase price
Lock_df=df.loc[["Lisosia93","Idastidru52","Chamjask73","Iral74", "Iskadarya95"],["Price","Item Name"]]
print(Lock_df)
# Out:
#              Price                                     Item Name
# SN
# Lisosia93     4.64             Blazefury, Protector of Delusions
# Lisosia93     3.81                                 Warped Fetish
# Lisosia93     4.80                       Spada, Etcher of Hatred
# Lisosia93     3.19                                    Persuasion
# Lisosia93     2.52                                 Second Chance
# Idastidru52   4.93             Hellreaver, Heirloom of Inception
# Idastidru52   4.03            Warmonger, Gift of Suffering's End
# Idastidru52   1.60                                      Massacre
# Idastidru52   4.89                                  Misery's End
# Chamjask73    4.23  Oathbreaker, Last Hope of the Breaking Storm
# Chamjask73    4.76              Downfall, Scalpel Of The Emperor
# Chamjask73    4.84                                        Hatred
# Iral74        4.14             Freak's Bite, Favor of Holy Might
# ...

# %%
#Create Data Frame based off of information

Top_Spenders=pd.DataFrame({"SN":["Lisosia93","Idastidru52","Chamjask73","Iral74", "Iskadarya95"],
                          "Purchase Count":[5,4,3,4,3],
                          "Average Purchase Price":[((4.64+3.81+4.80+3.19+2.52)/5),((4.93+4.03+1.60+4.89)/4),((4.23+4.76+4.84)/3),((4.14+3.82+4.03+1.63)/4),((4.03+4.90+4.17)/3)],
                          "Total Puchase value":["$18.96","$15.45","$13.83","$13.62","$13.10"]
                                                  })
Top_Spenders
# Out:
#             SN  Purchase Count  Average Purchase Price Total Puchase value
# 0    Lisosia93               5                3.792000              $18.96
# 1  Idastidru52               4                3.862500              $15.45
# 2   Chamjask73               3                4.610000              $13.83
# 3       Iral74               4                3.405000              $13.62
# 4  Iskadarya95               3                4.366667              $13.10

# %%
Cleaned_Up= pd.DataFrame({"SN":["Lisosia93","Idastidru52","Chamjask73","Iral74", "Iskadarya95"],
                         "Purchase Count":[5,4,3,4,3],
                          "Average Purchase Price":["$3.79","$3.86","$4.61","$3.41","$4.37"],
                         "Total Puchase value":["$18.96","$15.45","$13.83","$13.62","$13.10"]})
Cleaned_Up
# Out:
#             SN  Purchase Count Average Purchase Price Total Puchase value
# 0    Lisosia93               5                  $3.79              $18.96
# 1  Idastidru52               4                  $3.86              $15.45
# 2   Chamjask73               3                  $4.61              $13.83
# 3       Iral74               4                  $3.41              $13.62
# 4  Iskadarya95               3                  $4.37              $13.10

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
gamer_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Ranges
# 0  Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                          Frenzied Scimitar   1.56        40+
# 2                               Final Critic   4.88      20-24
# 3                                Blindscythe   3.27      20-24
# 4                                       Fury   1.44      20-24

# %%
#Most Popular Items
ID= gamer_df[["Item ID","Item Name"]].value_counts()
ID.head(20)
# Out:
# Item ID  Item Name
# 92       Final Critic                                    13
# 178      Oathbreaker, Last Hope of the Breaking Storm    12
# 108      Extraction, Quickblade Of Trembling Hands        9
# 132      Persuasion                                       9
# 82       Nirvana                                          9
# 145      Fiery Glass Crusader                             9
# 60       Wolf                                             8
# 34       Retribution Axe                                  8
# 37       Shadow Strike, Glory of Ending Hope              8
# 59       Lightning, Etcher of the King                    8
# 72       Winter's Bite                                    8
# 19       Pursuit, Cudgel of Necromancy                    8
# 103      Singed Scalpel                                   8
# 75       Brutality Ivory Warmace                          8
# 117      Heartstriker, Legacy of the Light                7
# ...

# %%
#Total count of Item ID and Name with price 
ID_Price= gamer_df[["Item ID","Item Name","Price"]]
ID_Price.value_counts().head(20)
# Out:
# Item ID  Item Name                                     Price
# 178      Oathbreaker, Last Hope of the Breaking Storm  4.23     12
# 145      Fiery Glass Crusader                          4.58      9
# 82       Nirvana                                       4.90      9
# 108      Extraction, Quickblade Of Trembling Hands     3.53      9
# 34       Retribution Axe                               2.22      8
# 75       Brutality Ivory Warmace                       2.42      8
# 92       Final Critic                                  4.88      8
# 72       Winter's Bite                                 3.77      8
# 19       Pursuit, Cudgel of Necromancy                 1.02      8
# 60       Wolf                                          3.54      8
# 103      Singed Scalpel                                4.35      8
# 37       Shadow Strike, Glory of Ending Hope           3.16      8
# 59       Lightning, Etcher of the King                 4.23      8
# ...

# %%
#Item Sum price
item_sum=item_group.sum()
item_sum

Sorting3_df = item_sum.sort_values("Price",ascending=False )
Sorting3_df.head(10)
# Out:
#                                                       Price
# Item ID Item Name
# 92      Final Critic                                  59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm  50.76
# 82      Nirvana                                       44.10
# 145     Fiery Glass Crusader                          41.22
# 103     Singed Scalpel                                34.80
# 59      Lightning, Etcher of the King                 33.84
# 108     Extraction, Quickblade Of Trembling Hands     31.77
# 78      Glimmer, Ender of the Moon                    30.80
# 72      Winter's Bite                                 30.16
# 132     Persuasion                                    28.99

# %%
item_count=item_group.count()
item_count

Sorting5_df = item_count.sort_values("Price",ascending=False )
Sorting5_df.head()
# Out:
#                                                       Price
# Item ID Item Name
# 92      Final Critic                                     13
# 178     Oathbreaker, Last Hope of the Breaking Storm     12
# 145     Fiery Glass Crusader                              9
# 132     Persuasion                                        9
# 108     Extraction, Quickblade Of Trembling Hands         9

# %%
most_popular=pd.DataFrame({"Item ID":[92,178,145,132,108],
                          "Item Name":["Final Critic","Oathbreaker Last Hope of the Breaking Storm","Fiery Glass Crusader","Persuasion","Extraction Quickblade Of Trembling Hands"],
                          "Purchase Count":[13,12,9,9,9],
                           "Item Price":["$4.88","$4.23","$4.58","$3.19","$3.53"],
                          "Total Purchase Value":[("$59.99"),("$50.76"),("$41.22"),("$28.99"),("$31.77")]})
most_popular
# Out:
#    Item ID                                    Item Name  Purchase Count  \
# 0       92                                 Final Critic              13
# 1      178  Oathbreaker Last Hope of the Breaking Storm              12
# 2      145                         Fiery Glass Crusader               9
# 3      132                                   Persuasion               9
# 4      108     Extraction Quickblade Of Trembling Hands               9
#
#   Item Price Total Purchase Value
# 0      $4.88               $59.99
# 1      $4.23               $50.76
# 2      $4.58               $41.22
# 3      $3.19               $28.99
# 4      $3.53               $31.77

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
